# %%
print("Hello Computational Materials Science")
# Out:
# Hello Computational Materials Science

# %%
print(2+3)
# Out:
# 5

# %%
print(10*5)
# Out:
# 50

# %%
atoms = 100
temperature = 300
print(atoms)
print(temperature)
# Out:
# 100
# 300

# %%
material = "Copper"
print(material)
# Out:
# Copper

# %%
material = "Copper"
temperature = 300
print(material, temperature)
# Out:
# Copper 300

# %% [markdown]
# ## Exercises##
# write a program to print the word steel

# %%
print("Steel")
# Out:
# Steel

# %%
#store two numbers in variables and add them together
a = 5
b = 10
print(a + b)
# Out:
# 15

# %%
# create a variable called density and assign it the value 7.85 g/cm^3. print the variable density.
density = 7.85
print(density)
# Out:
# 7.85
