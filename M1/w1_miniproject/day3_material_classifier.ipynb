# %%
density = float(input("Density: "))
strength = float(input("Strength MPa: "))

if density < 3 and strength > 300:
    print("Light structural candidate")
elif density > 7 and strength > 500:
    print("Heavy high-strength material")
else:
    print("General purpose material")
# Out:
# Heavy high-strength material
