# %%
# SESSION 4 — MINI PROJECT
# Build Your First Scientific Program (Upgraded)

material = "Aluminum"
density = 2.7
melting_point = 660
electrical_conductivity = 37.7   # MS/m (megasiemens per meter)
color = "Silver-gray"
cost_estimate = 2.50            # USD per kg (example estimate)

print("Material:", material)
print("Density:", density, "g/cm^3")
print("Melting Point:", melting_point, "°C")
print("Electrical Conductivity:", electrical_conductivity, "MS/m")
print("Color:", color)
print("Cost Estimate: $", cost_estimate, "per kg")
# Out:
# Material: Aluminum
# Density: 2.7 g/cm^3
# Melting Point: 660 °C
# Electrical Conductivity: 37.7 MS/m
# Color: Silver-gray
# Cost Estimate: $ 2.5 per kg
