# %% [markdown]
# ## MINI PROJECT
# Interactive Material Card

# %%
material = input("Material name: ")
density = float(input("Density g/cm^3: "))
melting = float(input("Melting point C: "))
cost = float(input("Cost per kg: "))

print("----- MATERIAL DATA -----")
print("Name:", material)
print("Density:", density)
print("Melting Point:", melting)
print("Cost per kg:", cost)
# Out:
# ----- MATERIAL DATA -----
# Name: Steel
# Density: 7.8
# Melting Point: 1200.0
# Cost per kg: 70.0
