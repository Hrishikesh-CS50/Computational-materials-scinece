# %% [markdown]
# # Mathematical Integration

# %% [markdown]
# ![image.png](attachment:image.png)
#
# This progression leads directly to transport physics.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. A derivative indicates the rate of change, integral accumulates all infinitisimal contributions. <br>
# A derivative represents the local rate of change of a quantity, while an integral represents the accumulation of infinitesimal contributions over a domain.<br>
# 2. because exact solutions are impossible for real world systems and using computers, hence approximations are used with acceptable error. it is important to note that there is always error in approximations<br>
# Simulations use approximations because most engineering systems are too complex for exact analytical solutions. Numerical methods approximate the governing equations with controlled and acceptable error.<br>
# 3. matrix for represents a group of objects. for example, nodes in the mesh<br>
# Matrices do not merely store groups of objects.<br>
#
# They usually represent:<br>
#
# relationships,<br>
# couplings,<br>
# transformations,<br>
# system equations.<br>
#
# Matrix form represents coupled relationships between multiple variables in a system. In FEM, matrices represent how nodes and elements interact physically through stiffness, mass, conductivity, or force relationships.<br>
# 4. Vectors are essential in mechanics because physical quantities like force, velocity, acceleration, and displacement have both magnitude and direction. Mechanics requires directional information to correctly represent motion, equilibrium, stress, and interactions in space.
