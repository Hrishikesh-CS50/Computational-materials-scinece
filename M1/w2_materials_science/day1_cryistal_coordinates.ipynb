# %% [markdown]
# # Materials Science: Crystal Coordinates

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Topic 5: Store Coordinates in Python
import numpy as np
fcc = np.array([
[0,0,0],
[0.5,0.5,0],
[0.5,0,0.5],
[0,0.5,0.5]
])

print(fcc)
# Out:
# [[0.  0.  0. ]
#  [0.5 0.5 0. ]
#  [0.5 0.  0.5]
#  [0.  0.5 0.5]]

# %% [markdown]
# ![image.png](attachment:image.png)
