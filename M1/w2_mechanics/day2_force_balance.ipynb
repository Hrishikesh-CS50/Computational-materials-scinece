# %% [markdown]
# # Force balance

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1.  Exercise 1
# ![image.png](attachment:image.png)

# %%
k1 = 100
k2 = 200

keq = k1 + k2

print("Equivalent spring constant =", keq)
# Out:
# Equivalent spring constant = 300

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
k1 = 100
k2 = 200

keq = 1 / (1/k1 + 1/k2)

print("Equivalent spring constant =", keq)
# Out:
# Equivalent spring constant = 66.66666666666667

# %% [markdown]
# # 2. exercise
#
# ![image.png](attachment:image.png)

# %%
P = 300
keq = 300

x = P / keq
print("Displacement =", x)
# Out:
# Displacement = 1.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
P = 300
keq = 66.67

x = P / keq
print("Displacement =", x)
# Out:
# Displacement = 4.4997750112494375

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
